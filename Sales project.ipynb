# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv(r"C:\Users\acer\Downloads\archive\business.retailsales.csv")
df1= pd.read_csv(r"C:\Users\acer\Downloads\archive\business.retailsales2.csv")

# %% [markdown]
# # Data cleaning( Category wise Sales(Table1))

# %%
df
# Out:
#          Product Type  Net Quantity  Gross Sales  Discounts  Returns  \
# 0     Art & Sculpture            34      14935.0    -594.00 -1609.00
# 1              Basket            13       3744.0    -316.80     0.00
# 2              Basket            12       3825.0    -201.60  -288.00
# 3              Basket            17       3035.0     -63.25     0.00
# 4     Art & Sculpture            47       2696.8     -44.16     0.00
# ...               ...           ...          ...        ...      ...
# 1770          Kitchen             0         28.0      -2.81   -25.19
# 1771          Jewelry             0         28.0       0.00   -28.00
# 1772           Basket             0        116.0     -23.20   -92.80
# 1773          Kitchen             0         16.5       0.00   -16.50
# 1774          Kitchen            -1          0.0       0.00  -106.25
#
#       Total Net Sales
# 0            12732.00
# 1             3427.20
# 2             3335.40
# 3             2971.75
# 4             2652.64
# ...               ...
# 1770             0.00
# 1771             0.00
# 1772             0.00
# 1773             0.00
# 1774          -106.25
#
# [1775 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1775 entries, 0 to 1774
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Product Type     1767 non-null   object
#  1   Net Quantity     1775 non-null   int64
#  2   Gross Sales      1775 non-null   float64
#  3   Discounts        1775 non-null   float64
#  4   Returns          1775 non-null   float64
#  5   Total Net Sales  1775 non-null   float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 83.3+ KB

# %%
df.dropna(inplace= True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1767 entries, 0 to 1774
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Product Type     1767 non-null   object
#  1   Net Quantity     1767 non-null   int64
#  2   Gross Sales      1767 non-null   float64
#  3   Discounts        1767 non-null   float64
#  4   Returns          1767 non-null   float64
#  5   Total Net Sales  1767 non-null   float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 96.6+ KB

# %%
df["Discounts"]=df['Discounts'].abs()

# %%
df["Returns"]=df['Returns'].abs()

# %%
df["Total Net Sales"]=df['Total Net Sales'].abs()

# %%
df["Net Quantity"]=df['Net Quantity'].abs()

# %%
df
# Out:
#          Product Type  Net Quantity  Gross Sales  Discounts  Returns  \
# 0     Art & Sculpture            34      14935.0     594.00  1609.00
# 1              Basket            13       3744.0     316.80     0.00
# 2              Basket            12       3825.0     201.60   288.00
# 3              Basket            17       3035.0      63.25     0.00
# 4     Art & Sculpture            47       2696.8      44.16     0.00
# ...               ...           ...          ...        ...      ...
# 1770          Kitchen             0         28.0       2.81    25.19
# 1771          Jewelry             0         28.0       0.00    28.00
# 1772           Basket             0        116.0      23.20    92.80
# 1773          Kitchen             0         16.5       0.00    16.50
# 1774          Kitchen             1          0.0       0.00   106.25
#
#       Total Net Sales
# 0            12732.00
# 1             3427.20
# 2             3335.40
# 3             2971.75
# 4             2652.64
# ...               ...
# 1770             0.00
# 1771             0.00
# 1772             0.00
# 1773             0.00
# 1774           106.25
#
# [1775 rows x 6 columns]

# %%
df2=df.groupby("Product Type").sum()

# %%
df2
# Out:
#                   Net Quantity  Gross Sales  Discounts  Returns  \
# Product Type
# Accessories                 84      3892.40     107.02     0.00
# Art & Sculpture           1427     90316.60    2955.82  2879.93
# Basket                    1461    143815.50    4584.42  4439.69
# Christmas                  575     15476.00     345.19   670.00
# Easter                       1        38.00       3.80     0.00
# Fair Trade Gifts           110      2258.00      53.33     0.00
# Furniture                   27      2034.00     169.04     0.00
# Gift Baskets                 1        19.50       0.00     0.00
# Home Decor                 404     27114.55     991.21   423.35
# Jewelry                    991     31048.00     965.85   509.20
# Kids                       140      3838.00     116.66     0.00
# Kitchen                    811     16096.00     431.11   328.07
# Music                       98      2643.50      82.19   142.41
# One-of-a-Kind               12      2180.00      71.99     0.00
# Recycled Art                99      3792.80      88.64     0.00
# Skin Care                  101      2609.50      37.70     0.00
# Soapstone                  199      4795.50      96.91    69.50
# Textiles                    43      1889.00     112.90    97.00
#
#                   Total Net Sales
# Product Type
# Accessories               3785.38
# Art & Sculpture          84480.85
# Basket                  134791.39
# Christmas                14460.81
# Easter                      34.20
# Fair Trade Gifts          2204.67
# Furniture                 1864.96
# Gift Baskets                19.50
# Home Decor               25699.99
# Jewelry                  29572.95
# Kids                      3721.34
# Kitchen                  15549.32
# Music                     2418.90
# One-of-a-Kind             2108.01
# Recycled Art              3704.16
# Skin Care                 2571.80
# Soapstone                 4629.09
# Textiles                  1679.10

# %%
df2=df2.reset_index()

# %%
df2
# Out:
#         Product Type  Net Quantity  Gross Sales  Discounts  Returns  \
# 0        Accessories            84      3892.40     107.02     0.00
# 1    Art & Sculpture          1427     90316.60    2955.82  2879.93
# 2             Basket          1461    143815.50    4584.42  4439.69
# 3          Christmas           575     15476.00     345.19   670.00
# 4             Easter             1        38.00       3.80     0.00
# 5   Fair Trade Gifts           110      2258.00      53.33     0.00
# 6          Furniture            27      2034.00     169.04     0.00
# 7       Gift Baskets             1        19.50       0.00     0.00
# 8         Home Decor           404     27114.55     991.21   423.35
# 9            Jewelry           991     31048.00     965.85   509.20
# 10              Kids           140      3838.00     116.66     0.00
# 11           Kitchen           811     16096.00     431.11   328.07
# 12             Music            98      2643.50      82.19   142.41
# 13     One-of-a-Kind            12      2180.00      71.99     0.00
# 14      Recycled Art            99      3792.80      88.64     0.00
# 15         Skin Care           101      2609.50      37.70     0.00
# 16         Soapstone           199      4795.50      96.91    69.50
# 17          Textiles            43      1889.00     112.90    97.00
#
#     Total Net Sales
# 0           3785.38
# 1          84480.85
# 2         134791.39
# 3          14460.81
# 4             34.20
# 5           2204.67
# 6           1864.96
# 7             19.50
# 8          25699.99
# 9          29572.95
# 10          3721.34
# 11         15549.32
# 12          2418.90
# 13          2108.01
# 14          3704.16
# 15          2571.80
# 16          4629.09
# 17          1679.10

# %% [markdown]
# ##

# %%
df.describe()
# Out:
#        Net Quantity   Gross Sales    Discounts      Returns  Total Net Sales
# count   1775.000000   1775.000000  1775.000000  1775.000000      1775.000000
# mean       3.713803    199.671746     6.317623     5.385437       188.088406
# std        6.242407    464.880638    20.903517    46.654269       414.492704
# min        0.000000      0.000000     0.000000     0.000000         0.000000
# 25%        1.000000     48.000000     0.000000     0.000000        44.900000
# 50%        2.000000    100.000000     0.000000     0.000000        96.000000
# 75%        4.000000    185.500000     6.000000     0.000000       184.750000
# max       96.000000  14935.000000   594.000000  1609.000000     12732.000000

# %% [markdown]
# # Data cleaning( year wise sales(Table1))

# %%
df1
# Out:
#         Month  Year  Total Orders  Gross Sales  Discounts  Returns  Net Sales  \
# 0     January  2017            73      8861.50    -129.40  -448.45    8283.65
# 1    February  2017            56      6908.50    -104.70  -416.20    6387.60
# 2       March  2017            60      5778.50    -172.20 -1017.20    4589.10
# 3       April  2017            70      8814.00    -281.40     0.00    8532.60
# 4         May  2017            54      6677.00    -185.75  -253.80    6237.45
# 5        June  2017            68      9621.50    -234.45   -17.50    9369.55
# 6        July  2017            66      6480.00     -51.50  -469.20    5959.30
# 7      August  2017            55      8025.00    -258.90   -26.00    7740.10
# 8   September  2017            68      7075.00     -61.70  -281.00    6732.30
# 9     October  2017            59      5720.00     -88.00  -305.00    5327.00
# 10   November  2017            91     13025.00    -131.30  -323.85   12569.85
# 11   December  2017           116     10356.05    -149.85  -414.20    9792.00
# 12    January  2018            83      8923.00    -217.10   -26.25    8679.65
# 13   February  2018            69      6529.20    -161.35  -118.15    6249.70
# 14      March  2018            64      7442.70    -226.82    -8.80    7207.08
# 15      April  2018            81      9406.35    -232.28   -40.00    9134.07
# 16        May  2018            82      7493.90    -221.25 -1448.02    5824.63
# 17       June  2018           124     13260.80    -335.40 -1506.53   11418.87
# 18       July  2018           102      9274.95    -237.87  -689.98    8347.10
# 19     August  2018            82      7698.70    -140.57  -197.35    7360.78
# 20  September  2018            79     10582.85    -276.15     0.00   10306.70
# 21    October  2018            71      7014.50    -277.95  -294.75    6441.80
# 22   November  2018           140     12002.70    -414.45  -154.40   11433.85
# 23   December  2018           164     13683.50    -371.20  -928.35   12383.95
# 24    January  2019            87      7811.75    -261.97 -1250.35    6299.43
# 25   February  2019            63      6523.70    -288.70   -38.70    6196.30
# 26      March  2019            99     13075.50    -439.85  -981.00   11654.65
# 27      April  2019            92      6977.00    -285.40   -10.00    6681.60
# 28        May  2019            96     10082.25    -460.90  -173.35    9448.00
# 29       June  2019            85      7321.75    -186.02  -165.40    6970.33
# 30       July  2019            94      9739.20    -447.07  -908.75    8383.38
# 31     August  2019           105      8839.50    -201.67   -84.37    8553.46
# 32  September  2019            88      9077.45    -354.89  -853.35    7869.21
# 33    October  2019            97      9132.25    -279.42 -1572.55    7280.28
# 34   November  2019           272     23997.90    -776.84  -364.51   22856.55
# 35   December  2019           342     31183.90   -2269.51 -1311.18   27603.21
#
#     Shipping  Total Sales
# 0    1088.30      9371.95
# 1     892.45      7280.05
# 2     707.43      5296.53
# 3    1068.30      9600.90
# 4     866.46      7103.91
# 5    1204.32     10573.87
# 6     807.36      6766.66
# 7     843.46      8583.56
# 8     907.32      7639.62
# 9     695.42      6022.42
# 10   1555.10     14124.95
# 11   1340.85     11132.85
# 12   1180.18      9859.83
# 13    908.91      7158.61
# 14   1226.92      8434.00
# 15   1387.56     10521.63
# 16   1234.95      7059.58
# 17   2124.49     13543.36
# 18   1627.03      9974.13
# 19   1404.03      8764.81
# 20   1634.33     11941.03
# 21   1262.45      7704.25
# 22   2237.05     13670.90
# 23   2552.20     14936.15
# 24   1313.78      7615.91
# 25   1121.85      7318.15
# 26   2115.10     13769.75
# 27   1342.45      8024.05
# 28   1768.20     11216.20
# 29   1356.80      8327.13
# 30   1631.40     10014.78
# 31   1724.75     10278.21
# 32   1567.65      9436.86
# 33   1631.25      8911.53
# 34   4824.75     27681.30
# 35   5703.25     33306.46

# %%
df1["Discounts"]=df1["Discounts"].abs()

# %%
df1["Returns"]=df1["Returns"].abs()

# %%
df1
# Out:
#         Month  Year  Total Orders  Gross Sales  Discounts  Returns  Net Sales  \
# 0     January  2017            73      8861.50     129.40   448.45    8283.65
# 1    February  2017            56      6908.50     104.70   416.20    6387.60
# 2       March  2017            60      5778.50     172.20  1017.20    4589.10
# 3       April  2017            70      8814.00     281.40     0.00    8532.60
# 4         May  2017            54      6677.00     185.75   253.80    6237.45
# 5        June  2017            68      9621.50     234.45    17.50    9369.55
# 6        July  2017            66      6480.00      51.50   469.20    5959.30
# 7      August  2017            55      8025.00     258.90    26.00    7740.10
# 8   September  2017            68      7075.00      61.70   281.00    6732.30
# 9     October  2017            59      5720.00      88.00   305.00    5327.00
# 10   November  2017            91     13025.00     131.30   323.85   12569.85
# 11   December  2017           116     10356.05     149.85   414.20    9792.00
# 12    January  2018            83      8923.00     217.10    26.25    8679.65
# 13   February  2018            69      6529.20     161.35   118.15    6249.70
# 14      March  2018            64      7442.70     226.82     8.80    7207.08
# 15      April  2018            81      9406.35     232.28    40.00    9134.07
# 16        May  2018            82      7493.90     221.25  1448.02    5824.63
# 17       June  2018           124     13260.80     335.40  1506.53   11418.87
# 18       July  2018           102      9274.95     237.87   689.98    8347.10
# 19     August  2018            82      7698.70     140.57   197.35    7360.78
# 20  September  2018            79     10582.85     276.15     0.00   10306.70
# 21    October  2018            71      7014.50     277.95   294.75    6441.80
# 22   November  2018           140     12002.70     414.45   154.40   11433.85
# 23   December  2018           164     13683.50     371.20   928.35   12383.95
# 24    January  2019            87      7811.75     261.97  1250.35    6299.43
# 25   February  2019            63      6523.70     288.70    38.70    6196.30
# 26      March  2019            99     13075.50     439.85   981.00   11654.65
# 27      April  2019            92      6977.00     285.40    10.00    6681.60
# 28        May  2019            96     10082.25     460.90   173.35    9448.00
# 29       June  2019            85      7321.75     186.02   165.40    6970.33
# 30       July  2019            94      9739.20     447.07   908.75    8383.38
# 31     August  2019           105      8839.50     201.67    84.37    8553.46
# 32  September  2019            88      9077.45     354.89   853.35    7869.21
# 33    October  2019            97      9132.25     279.42  1572.55    7280.28
# 34   November  2019           272     23997.90     776.84   364.51   22856.55
# 35   December  2019           342     31183.90    2269.51  1311.18   27603.21
#
#     Shipping  Total Sales
# 0    1088.30      9371.95
# 1     892.45      7280.05
# 2     707.43      5296.53
# 3    1068.30      9600.90
# 4     866.46      7103.91
# 5    1204.32     10573.87
# 6     807.36      6766.66
# 7     843.46      8583.56
# 8     907.32      7639.62
# 9     695.42      6022.42
# 10   1555.10     14124.95
# 11   1340.85     11132.85
# 12   1180.18      9859.83
# 13    908.91      7158.61
# 14   1226.92      8434.00
# 15   1387.56     10521.63
# 16   1234.95      7059.58
# 17   2124.49     13543.36
# 18   1627.03      9974.13
# 19   1404.03      8764.81
# 20   1634.33     11941.03
# 21   1262.45      7704.25
# 22   2237.05     13670.90
# 23   2552.20     14936.15
# 24   1313.78      7615.91
# 25   1121.85      7318.15
# 26   2115.10     13769.75
# 27   1342.45      8024.05
# 28   1768.20     11216.20
# 29   1356.80      8327.13
# 30   1631.40     10014.78
# 31   1724.75     10278.21
# 32   1567.65      9436.86
# 33   1631.25      8911.53
# 34   4824.75     27681.30
# 35   5703.25     33306.46

# %%
sales_by_year= df1.groupby("Year").sum(['Total Orders', 'Gross Sales', 'Discounts', 'Returns', 'Net Sales', 'Shipping', 'Total Sales'])

# %%
sales_by_year
# Out:
#       Total Orders  Gross Sales  Discounts  Returns  Net Sales  Shipping  \
# Year
# 2017           836     97342.05    1849.15  3972.40   91520.50  11976.77
# 2018          1141    113313.15    3112.39  5412.58  104788.18  18780.10
# 2019          1520    143762.15    6252.24  7713.51  129796.40  26101.23
#
#       Total Sales
# Year
# 2017    103497.27
# 2018    123568.28
# 2019    155900.33

# %%
sales_by_year.reset_index(inplace= True)
sales_by_year
# Out:
#    Year  index  Total Orders  Gross Sales  Discounts  Returns  Net Sales  \
# 0  2017      0           836     97342.05    1849.15  3972.40   91520.50
# 1  2018      1          1141    113313.15    3112.39  5412.58  104788.18
# 2  2019      2          1520    143762.15    6252.24  7713.51  129796.40
#
#    Shipping  Total Sales
# 0  11976.77    103497.27
# 1  18780.10    123568.28
# 2  26101.23    155900.33

# %%
average_sales= df1.groupby("Year").mean(['Total Orders' , 'Gross Sales', 'Discounts', 'Returns', 'Net Sales', 'Shipping', 'Total Sales'])

# %%
average_sales
# Out:
#       Total Orders   Gross Sales   Discounts     Returns     Net Sales  \
# Year
# 2017     69.666667   8111.837500  154.095833  331.033333   7626.708333
# 2018     95.083333   9442.762500  259.365833  451.048333   8732.348333
# 2019    126.666667  11980.179167  521.020000  642.792500  10816.366667
#
#          Shipping   Total Sales
# Year
# 2017   998.064167   8624.772500
# 2018  1565.008333  10297.356667
# 2019  2175.102500  12991.694167

# %% [markdown]
# # EXPLANATORY DATA ANALYSIS

# %%
qty_sold_by_category=df2[["Product Type", "Net Quantity"]]
qty_sold_by_category
# Out:
#         Product Type  Net Quantity
# 0        Accessories            84
# 1    Art & Sculpture          1427
# 2             Basket          1461
# 3          Christmas           575
# 4             Easter             1
# 5   Fair Trade Gifts           110
# 6          Furniture            27
# 7       Gift Baskets             1
# 8         Home Decor           404
# 9            Jewelry           991
# 10              Kids           140
# 11           Kitchen           811
# 12             Music            98
# 13     One-of-a-Kind            12
# 14      Recycled Art            99
# 15         Skin Care           101
# 16         Soapstone           199
# 17          Textiles            43

# %%
qty_sold_by_category
# Out:
#                   Net Quantity
# Product Type
# Accessories                 84
# Art & Sculpture           1427
# Basket                    1461
# Christmas                  575
# Easter                       1
# Fair Trade Gifts           110
# Furniture                   27
# Gift Baskets                 1
# Home Decor                 404
# Jewelry                    991
# Kids                       140
# Kitchen                    811
# Music                       98
# One-of-a-Kind               12
# Recycled Art                99
# Skin Care                  101
# Soapstone                  199
# Textiles                    43

# %%
qty_sold_by_category.plot(kind="pie", y="Net Quantity",figsize=(10,6), legend=False, title= "Qty sold category wise");

# %%
Total_sales_category_wise=df2[["Product Type", "Total Net Sales"]]
Total_sales_category_wise
# Out:
#         Product Type  Total Net Sales
# 0        Accessories          3785.38
# 1    Art & Sculpture         84480.85
# 2             Basket        134791.39
# 3          Christmas         14460.81
# 4             Easter            34.20
# 5   Fair Trade Gifts          2204.67
# 6          Furniture          1864.96
# 7       Gift Baskets            19.50
# 8         Home Decor         25699.99
# 9            Jewelry         29572.95
# 10              Kids          3721.34
# 11           Kitchen         15549.32
# 12             Music          2418.90
# 13     One-of-a-Kind          2108.01
# 14      Recycled Art          3704.16
# 15         Skin Care          2571.80
# 16         Soapstone          4629.09
# 17          Textiles          1679.10

# %%
sns.barplot(x="Product Type", y="Total Net Sales", data=Total_sales_category_wise).set(title="Total sales category wise($)")
plt.xticks(rotation= 90);

# %%
Discount=df2[["Product Type", "Discounts"  ]]
Discount.set_index("Product Type", inplace= True)
Discount
# Out:
#                   Discounts
# Product Type
# Accessories          107.02
# Art & Sculpture     2955.82
# Basket              4584.42
# Christmas            345.19
# Easter                 3.80
# Fair Trade Gifts      53.33
# Furniture            169.04
# Gift Baskets           0.00
# Home Decor           991.21
# Jewelry              965.85
# Kids                 116.66
# Kitchen              431.11
# Music                 82.19
# One-of-a-Kind         71.99
# Recycled Art          88.64
# Skin Care             37.70
# Soapstone             96.91
# Textiles             112.90

# %%
Discount.plot(kind="barh", xlabel="Discounts", ylabel="Product Type", title=" Discount($)", legend= False, figsize=(10,7));

# %%
product_returned=df2[["Product Type", "Returns"]]
product_returned.reset_index()
product_returned
# Out:
#         Product Type  Returns
# 0        Accessories     0.00
# 1    Art & Sculpture  2879.93
# 2             Basket  4439.69
# 3          Christmas   670.00
# 4             Easter     0.00
# 5   Fair Trade Gifts     0.00
# 6          Furniture     0.00
# 7       Gift Baskets     0.00
# 8         Home Decor   423.35
# 9            Jewelry   509.20
# 10              Kids     0.00
# 11           Kitchen   328.07
# 12             Music   142.41
# 13     One-of-a-Kind     0.00
# 14      Recycled Art     0.00
# 15         Skin Care     0.00
# 16         Soapstone    69.50
# 17          Textiles    97.00

# %%
sns.barplot(x="Product Type", y="Returns", data=product_returned ).set(title="Product returned($)")
plt.xticks(rotation= 90);

# %%
annual_sales=sales_by_year[["Year", "Total Sales"]]

# %%
annual_sales.plot(kind="line", x="Year", y="Total Sales", title="Annual Sales", legend= False);

# %%
sns.barplot(x="Year", y="Total Orders", data= sales_by_year).set(title="Quantity sold");

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# Baskets and Art&Sculptures are the most sold items of the business which generates most of the revenue,
# whereas Easter and Gift baskets are the least sold products of the business.
#
# The annual sales of the business is growing every year at certain rate without showing any diminishing values.
